# %% [markdown]
# ## Monte Carlo - Predicting Gross Profit - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Imagine you are an experienced manager and you have forecasted revenues of \$200mln, with an expected deviation of $10mln. You are convinced Cogs will be near 40% of the revenues, and their expected deviation is 20% of its own value.

# %% [markdown]
# Use NumPy’s random.random function to simulate the potential revenue stream for 250 iterations (which is the number of trading days in a year) and then the predicted Cogs value.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev_m = 200
rev_stdev = 10
iterations = 250

# %%
rev =  np.random.normal(rev_m, rev_stdev, iterations)
rev
# Out:
# array([193.26631077, 208.49146179, 199.50234383, 195.30636561,
#        218.80988003, 204.2356767 , 183.40258858, 200.44605504,
#        194.50821106, 204.18657625, 197.76513837, 193.10042254,
#        198.50567697, 187.6644396 , 194.83838295, 215.87263103,
#        193.11339325, 209.02448205, 216.43694675, 203.54041922,
#        193.49030757, 197.48444839, 210.54332306, 189.19597545,
#        212.56184618, 201.10320276, 189.52093457, 195.90915165,
#        208.56327366, 194.02923938, 192.26748999, 218.29952597,
#        180.26467347, 187.05551319, 197.69215735, 192.87639435,
#        206.35132296, 223.5107975 , 202.62036063, 199.20348739,
#        186.80848049, 203.40494109, 192.27031586, 189.69978087,
#        191.81516939, 214.37049523, 201.81982585, 194.76564771,
#        205.62855089, 194.03503994, 196.06044334, 203.27916843,
#        206.78633303, 188.92229627, 216.47130781, 205.41497443,
#        206.89030152, 185.03713255, 190.12513431, 212.3977303 ,
#        202.48644079, 180.44056986, 184.77921062, 207.47976346,
#        201.98959908, 190.06613823, 205.7642264 , 211.78978587,
#        204.55997004, 211.26822471, 190.65612447, 213.10393698,
#        205.17638648, 204.4931264 , 183.07260229, 195.33112662,
#        208.22386776, 211.6305359 , 199.21540917, 201.43221582,
#        197.34041952, 215.20821705, 213.36611177, 213.8038051 ,
#        212.24789789, 194.28657901, 191.27034751, 205.3581117 ,
#        207.59744309, 181.84784034, 193.31370947, 222.61490488,
#        198.9280127 , 181.80821834, 213.55629924, 204.34520168,
#        214.3565525 , 191.67925997, 199.22761992, 203.15728524,
#        188.52444548, 202.40900556, 188.79816027, 203.37706017,
#        205.56642452, 195.80035817, 194.23074675, 195.74932284,
#        193.93083137, 184.59343623, 191.75376534, 193.33941836,
#        208.51396745, 209.92158693, 216.12242362, 197.10821765,
#        177.03026341, 196.3127677 , 211.81534819, 185.50282953,
#        191.17410086, 205.90319522, 199.3195945 , 195.64553196,
#        192.35314154, 202.22245432, 190.96278607, 190.87870183,
#        198.02758027, 211.38731799, 205.71134649, 196.78292973,
#        206.06668494, 208.08527736, 197.25430317, 224.07969908,
#        215.44876016, 195.74879718, 203.46166571, 214.7806392 ,
#        184.6303329 , 221.1700844 , 204.62125359, 217.97328402,
#        221.18689575, 197.54530033, 203.14319334, 209.24655883,
#        209.81763248, 185.41335224, 199.33432874, 196.86585798,
#        202.72418649, 217.7221062 , 199.98729593, 194.16274941,
#        212.80109916, 206.62105481, 211.78922595, 199.07196697,
#        206.2324016 , 192.10430831, 196.30152095, 205.15627829,
#        209.31843171, 205.25492307, 209.93748468, 193.70604452,
#        203.09729043, 221.85041931, 213.15214894, 189.09315712,
#        215.8485217 , 205.90714167, 202.29740847, 211.2126556 ,
#        191.24261901, 204.07763619, 213.25331553, 198.20170248,
#        200.84953318, 201.88832579, 192.97197736, 203.94454761,
#        196.70422062, 196.40693228, 206.17478787, 179.75365862,
#        210.9235057 , 193.69854249, 196.43806054, 189.52274754,
#        185.74897502, 185.55235618, 193.89381587, 213.19649684,
#        201.91421166, 193.21065816, 195.37161248, 183.72170398,
#        196.91536763, 187.32898627, 188.40650884, 190.18453662,
#        215.96783005, 205.76160613, 210.18860556, 212.79754187,
#        189.09563972, 175.01044574, 213.67872282, 200.26132362,
#        192.72206033, 192.18237873, 187.99809154, 199.3835775 ,
#        216.56484328, 190.54717259, 199.4138496 , 182.57179374,
#        204.54370829, 211.30652364, 200.01095802, 200.98059048,
#        184.24225147, 201.11550871, 210.18819706, 211.38030306,
#        215.01897729, 184.65123301, 194.63852912, 205.81546703,
#        192.82754898, 199.1461321 , 192.69943005, 201.73857498,
#        198.04398053, 199.7939743 , 211.39175292, 199.90967756,
#        199.61135148, 206.24523959, 199.90627534, 204.38259039,
#        199.17289815, 207.77246833, 192.74483648, 193.58140199,
#        199.62922399, 196.17236514])

# %% [markdown]
# Plot the obtained data for revenues and Cogs on a graph and observe the behavior of the obtained values.

# %%
plt.figure(figsize=(15, 6))
plt.plot(rev)
plt.show()

# %%
COGS = -(rev * np.random.normal(0.4, 0.2))

plt.figure(figsize=(15, 6))
plt.plot(COGS)
plt.show()

# %% [markdown]
# Cogs mean:

# %%
COGS.mean()
# Out:
# -65.06910641368849

# %% [markdown]
# Cogs std:

# %%
COGS.std()
# Out:
# 3.230909604029298
