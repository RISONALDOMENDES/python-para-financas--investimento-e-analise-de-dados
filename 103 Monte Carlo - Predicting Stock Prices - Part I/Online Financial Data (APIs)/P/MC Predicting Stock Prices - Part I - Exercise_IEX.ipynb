# %% [markdown]
# ## Monte Carlo - Forecasting Stock Prices - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Download the data for Microsoft (‘MSFT’) from IEX for the period ‘2015-1-1’ until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline
import yfinance as yf

ticker = ['MSFT']

data = yf.download(ticker, start='2015-01-01', end='2018-06-16')['Close']

data
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2015-01-02     46.759998
# 2015-01-05     46.330002
# 2015-01-06     45.650002
# 2015-01-07     46.230000
# 2015-01-08     47.590000
#                  ...
# 2018-06-11    101.050003
# 2018-06-12    101.309998
# 2018-06-13    100.849998
# 2018-06-14    101.419998
# 2018-06-15    100.129997
# Name: Close, Length: 870, dtype: float64

# %% [markdown]
# Use the .pct_change() method to obtain the log returns of Microsoft for the designated period.

# %%
log_returns = np.log(1 + data.pct_change())

# %%
log_returns.tail()
# Out:
# Date
# 2018-06-11   -0.005723
# 2018-06-12    0.002570
# 2018-06-13   -0.004551
# 2018-06-14    0.005636
# 2018-06-15   -0.012801
# Name: Close, dtype: float64

# %%
data.plot(figsize=(10, 6));

# %%
log_returns.plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Assign the mean value of the log returns to a variable, called “U”, and their variance to a variable, called “var”.

# %%
u = log_returns.mean()
u
# Out:
# 0.0008762269431312287

# %%
var = log_returns.var()
var
# Out:
# 0.00021287788334827199

# %% [markdown]
# Calculate the drift, using the following formula:
#
# $$
# drift = u - \frac{1}{2} \cdot var
# $$

# %%
drift = u - (0.5 * var)
drift
# Out:
# 0.0007697880014570928

# %% [markdown]
# Store the standard deviation of the log returns in a variable, called “stdev”.

# %%
stdev = log_returns.std()
stdev
# Out:
# 0.014590335271962464

# %% [markdown]
# ******

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)

# %% [markdown]
# analisando ITUSA

# %%
ativo = ['ITSA4.SA']

tabela = yf.download(ativo, start='2014-01-01')['Close']

tabela
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2014-01-02    4.861033
# 2014-01-03    4.877643
# 2014-01-06    4.910861
# 2014-01-07    4.894252
# 2014-01-08    4.921934
#                 ...
# 2024-06-18    9.710000
# 2024-06-19    9.810000
# 2024-06-20    9.800000
# 2024-06-21    9.680000
# 2024-06-24    9.880000
# Name: Close, Length: 2604, dtype: float64

# %%
tabela.head()
# Out:
# Date
# 2014-01-02    4.861033
# 2014-01-03    4.877643
# 2014-01-06    4.910861
# 2014-01-07    4.894252
# 2014-01-08    4.921934
# Name: Close, dtype: float64

# %%
tabela.tail()
# Out:
# Date
# 2024-06-18    9.71
# 2024-06-19    9.81
# 2024-06-20    9.80
# 2024-06-21    9.68
# 2024-06-24    9.88
# Name: Close, dtype: float64

# %% [markdown]
# metodo pct_change

# %%
retorno_log = np.log(1 + tabela.pct_change())

retorno_log.tail()
# Out:
# Date
# 2024-06-18    0.007235
# 2024-06-19    0.010246
# 2024-06-20   -0.001020
# 2024-06-21   -0.012320
# 2024-06-24    0.020451
# Name: Close, dtype: float64

# %%
tabela.plot(figsize=(10, 6));

# %%
retorno_log.plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
u_Br = retorno_log.mean()
u_Br
# Out:
# 0.000272478511036833

# %%
var_Br = retorno_log.var()
var
# Out:
# 0.00021287788334827199

# %% [markdown]
# calculando o drift

# %%
drift = u_Br - (0.5 * var_Br)

drift
# Out:
# 9.579714540116878e-05

# %% [markdown]
# desvio padrao

# %%
std_Br = retorno_log.std()

std_Br
# Out:
# 0.018797944868291547

# %% [markdown]
# 5 anos

# %%
tabela_2 = yf.download(ativo, start='2019-01-01')['Close']
tabela_2
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2019-01-02    10.386908
# 2019-01-03    10.477229
# 2019-01-04    10.444385
# 2019-01-07    10.436174
# 2019-01-08    10.575761
#                 ...
# 2024-06-18     9.710000
# 2024-06-19     9.810000
# 2024-06-20     9.800000
# 2024-06-21     9.680000
# 2024-06-24     9.860000
# Name: Close, Length: 1361, dtype: float64

# %%
retorno_log_2 = np.log(1 + tabela_2.pct_change())
retorno_log_2.tail()
# Out:
# Date
# 2024-06-18    0.007235
# 2024-06-19    0.010246
# 2024-06-20   -0.001020
# 2024-06-21   -0.012320
# 2024-06-24    0.018424
# Name: Close, dtype: float64

# %%
tabela_2.plot(figsize=(10, 6));

# %%
retorno_log_2.plot(figsize=(10, 6));

# %%
u_Br_2 = retorno_log_2.mean()
u_Br_2
# Out:
# -3.827940625844468e-05

# %%
var_Br_2 = retorno_log_2.var()
var_Br_2
# Out:
# 0.0003254784743804465

# %%
drift_2 = u_Br_2 - (0.5 * var_Br_2)
drift_2
# Out:
# -0.00020101864344866796

# %%
std_Br_2 = retorno_log_2.std()

std_Br_2
# Out:
# 0.018041021988247963
