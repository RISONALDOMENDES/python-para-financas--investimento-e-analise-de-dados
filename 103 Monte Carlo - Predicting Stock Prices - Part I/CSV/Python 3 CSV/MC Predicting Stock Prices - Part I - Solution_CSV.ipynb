# %% [markdown]
# ## Monte Carlo - Forecasting Stock Prices - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Load the data for Microsoft (‘MSFT’) for the period ‘2000-1-1’ until today.

# %%
import numpy as np  
import pandas as pd  
from pandas_datareader import data as wb  
import matplotlib.pyplot as plt  
from scipy.stats import norm
# %matplotlib inline

data = pd.read_csv('MSFT_2000.csv', index_col = 'Date')

# %% [markdown]
# Use the .pct_change() method to obtain the log returns of Microsoft for the designated period.

# %%
log_returns = np.log(1 + data.pct_change())

# %%
log_returns.tail()
# Out:
#                 MSFT
# Date
# 2017-10-12  0.009118
# 2017-10-13  0.004786
# 2017-10-16  0.002063
# 2017-10-17 -0.000773
# 2017-10-18  0.000258

# %%
data.plot(figsize=(10, 6));

# %%
log_returns.plot(figsize = (10, 6))

# %% [markdown]
# Assign the mean value of the log returns to a variable, called “U”, and their variance to a variable, called “var”.

# %%
u = log_returns.mean()
u
# Out:
# MSFT    0.000154
# dtype: float64

# %%
var = log_returns.var()
var
# Out:
# MSFT    0.000376
# dtype: float64

# %% [markdown]
# Calculate the drift, using the following formula:
#
# $$
# drift = u - \frac{1}{2} \cdot var
# $$

# %%
drift = u - (0.5 * var)
drift
# Out:
# MSFT   -0.000034
# dtype: float64

# %% [markdown]
# Store the standard deviation of the log returns in a variable, called “stdev”.

# %%
stdev = log_returns.std()
stdev
# Out:
# MSFT    0.019397
# dtype: float64

# %% [markdown]
# ******

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)

# %%
import yfinance as yf

ativo = ['ITSA4.SA']

data_Br = yf.download(ativo, start='2014-01-01', end='2024-01-01')['Adj Close'];

data_Br
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2014-01-02    2.677342
# 2014-01-03    2.686490
# 2014-01-06    2.704785
# 2014-01-07    2.695638
# 2014-01-08    2.710884
#                 ...
# 2023-12-21    9.613202
# 2023-12-22    9.755972
# 2023-12-26    9.784526
# 2023-12-27    9.860669
# 2023-12-28    9.870189
# Name: Adj Close, Length: 2484, dtype: float64

# %% [markdown]
# retorno logaritimo

# %%
log_returns_Br = np.log(1 + data_Br.pct_change())
log_returns_Br
# Out:
# Date
# 2014-01-02         NaN
# 2014-01-03    0.003411
# 2014-01-06    0.006787
# 2014-01-07   -0.003387
# 2014-01-08    0.005640
#                 ...
# 2023-12-21    0.007952
# 2023-12-22    0.014742
# 2023-12-26    0.002923
# 2023-12-27    0.007752
# 2023-12-28    0.000965
# Name: Adj Close, Length: 2484, dtype: float64

# %%
log_returns_Br.tail()
# Out:
# Date
# 2023-12-21    0.007952
# 2023-12-22    0.014742
# 2023-12-26    0.002923
# 2023-12-27    0.007752
# 2023-12-28    0.000965
# Name: Adj Close, dtype: float64

# %%
data_Br.plot(figsize=(10, 6));

# %%
log_returns_Br.plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# media e variancia do retorno logaritimo

# %%
u_Br = log_returns_Br.mean()
u_Br
# Out:
# 0.0005254508956911694

# %%
var_Br = log_returns_Br.var()
var_Br
# Out:
# 0.0003600027007873727

# %% [markdown]
# calculo do drift

# %%
drift_Br = u_Br - (0.5 * var_Br)

drift_Br
# Out:
# 0.000345449545297483

# %% [markdown]
# desvio padrao do retorono lagaritmo

# %%
stdev_Br = log_returns_Br.std()

stdev_Br
# Out:
# 0.018973737132873238
